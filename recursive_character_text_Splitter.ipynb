# %%
from langchain_community.document_loaders import WikipediaLoader
wiki_loader = WikipediaLoader(query="Islam and Democracy", load_max_docs=2)
wiki_docs= wiki_loader.load()
wiki_docs[0].metadata["summary"]
# Out:
# 'There exist a number of perspectives on the relationship of Islam and democracy among Islamic political theorists, the general Muslim public, and Western authors.\nMany Muslim scholars have argued that traditional Islamic notions such as shura (consultation), maslaha (public interest), and ʿadl (justice) justify representative government institutions which are similar to Western democracy, but reflect Islamic rather than Western liberal values. Still others have advanced liberal democratic models of Islamic politics based on pluralism and freedom of thought. Some Muslim thinkers have advocated secularist views of Islam.\nA number of different attitudes regarding democracy are also represented among the general Muslim public, with polls indicating that majorities in the Muslim world desire a religious democracy where democratic institutions and values can coexist with the values and principles of Islam, seeing no contradiction between the two.'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=20)
splitted_docs = text_splitter.split_documents(wiki_docs)
splitted_docs
# Out:
# [Document(metadata={'title': 'Islam and democracy', 'summary': 'There exist a number of perspectives on the relationship of Islam and democracy among Islamic political theorists, the general Muslim public, and Western authors.\nMany Muslim scholars have argued that traditional Islamic notions such as shura (consultation), maslaha (public interest), and ʿadl (justice) justify representative government institutions which are similar to Western democracy, but reflect Islamic rather than Western liberal values. Still others have advanced liberal democratic models of Islamic politics based on pluralism and freedom of thought. Some Muslim thinkers have advocated secularist views of Islam.\nA number of different attitudes regarding democracy are also represented among the general Muslim public, with polls indicating that majorities in the Muslim world desire a religious democracy where democratic institutions and values can coexist with the values and principles of Islam, seeing no contradi
# ...

# %%
splitted_docs[0]
# Out:
# Document(metadata={'title': 'Islam and democracy', 'summary': 'There exist a number of perspectives on the relationship of Islam and democracy among Islamic political theorists, the general Muslim public, and Western authors.\nMany Muslim scholars have argued that traditional Islamic notions such as shura (consultation), maslaha (public interest), and ʿadl (justice) justify representative government institutions which are similar to Western democracy, but reflect Islamic rather than Western liberal values. Still others have advanced liberal democratic models of Islamic politics based on pluralism and freedom of thought. Some Muslim thinkers have advocated secularist views of Islam.\nA number of different attitudes regarding democracy are also represented among the general Muslim public, with polls indicating that majorities in the Muslim world desire a religious democracy where democratic institutions and values can coexist with the values and principles of Islam, seeing no contradic
# ...

# %%
from langchain_community.document_loaders import TextLoader

txt_loader = TextLoader("speech.txt")
txt_docs = txt_loader.load()
txt_docs

# %%
speech = ""
with open("speech.txt") as f:
    speech = f.read()
speech

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

txt_splitter = RecursiveCharacterTextSplitter(chunk_size= 20, chunk_overlap= 10)
txt = txt_splitter.create_documents([speech])
print(speech)
